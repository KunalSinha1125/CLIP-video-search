# %%
import string
text_dir = "AllVideoDescriptions.txt"

# %%
vid2tex = {}
with open(text_dir) as f:
    lines = f.readlines()
    for line in lines:
        if line[0] == '#' or line.isspace():
            continue
        splits = line.split()
        vid_name = splits[0]
        if vid_name not in vid2tex.keys():
            vid2tex[vid_name] = [' '.join( splits[1:])]
        else:
            vid2tex[vid_name].append(' '.join( splits[1:]))
vid2tex
# Out:
# {'-4wsuPCjDBc_5_15': ['a squirrel is eating a peanut in it s shell',
#   'a chipmunk is eating',
#   'a chipmunk is eating a peanut',
#   'a chipmunk is eating a nut',
#   'a squirrel is eating a nut',
#   'a squirrel is eating a whole peanut',
#   'a squirrel is eating a peanut',
#   'a squirrel l is eating nuts',
#   'a small squirrel is eating a peanut',
#   'a small animal is chewing on a nut',
#   'an ardilla is eating',
#   'a squirrel is eating a nut',
#   'a chipmunk is eating some food',
#   'the squirrel is eating',
#   'a ferret eats a leaf',
#   'a hamster is eating a peanut',
#   'a ardilla coreana eating',
#   'the rabbit is eating',
#   'a chipmunk is eating a peanut',
#   'a rabbit is eating',
#   'a rabbit is eating',
#   'a squirrel eating a fruit',
#   'a chipmunk is eating',
#   'a man is playing guitar',
#   'a squirrel or some such animal eating a nut of some kind',
#   'a chipmunk is eating some food',
#   'a rat is playing and eating something',
#   'the squirrel ate the peanut out of the shell',
#   'the squirrel is eating'],
#  '-7KMZQEsJW4_205_208': ['a man demonstrating how to clean a flower',
#   'a man brushes off the roots of a sunflower',
#   'a man holding two dried sunflowers is talking while dusting off the center portion of one flower',
#   'a man is brushing dirt off a sunflower',
#   'a man is brushing or patting the top of a sunflower with his hand',
#   'a man is holding dead sunflowers',
#   'a man is holding huge sunflowers',
#   'a man is holding two sunflowers',
#   'a man is knocking seeds out of a sunflower',
#   'a man is rubbing the head of a sunflower with his hand',
#   'a man is showing sunflowers',
#   'a man is tapping a sunflower',
#   'a man rubs a sunflower',
#   'a man rubs a sunflower',
#   'a man showed a sunflower head',
#   'someone is holding sunflowers',
#   'the man exhibited a sunflower head',
#   'the man is brushing dry sunflowers',
#   'virginia farm bureau in the garden sunflowers',
#   'a guy is holding the sunflower in his hand',
#   'a man is clearing sunflower',
#   'a man is holding two sunflowers',
#   'a man is picking some sunflowers',
#   'a man show flower in the garden',
#   'a man showing a sunflower',
#   'one man taking sunflower in his hands',
#   'virgina farm bureau and the garden full of sunflower',
#   'virginia farm bureau in the garden sunflowers',
#   'a man examine the dried sunflowers',
#   'a man extracting sunflower from a farm',
#   'a man in flower garden',
#   'a man is brushing off a dead sunflower',
#   'a man is harvesting sunflowers',
#   'a man is holding some sunflowers',
#   'a man is holding the sun flower',
#   'a man is seeding',
#   'a man is showing flowers',
#   'a man is stroking a sunflower s seed pod',
#   'a man is talking about flowers',
#   'a man is talking about sun flower',
#   'a man is talking',
#   'a man shows seeds of a dried sunflower'],
#  '-8y1Q0rA3n8_108_115': ['a man slices through a two liter plastic bottle of soda pop with a sword',
#   'a man slices a soda bottle with a sword',
#   'a man slices a soda bottle with a sword',
#   'a man uses a sword to cut a two liter plastic bottle in half',
#   'a man is broken a bottle by a sword',
#   'a man sliced a plastic bottle with a sword',
#   'a man is cutting a bottle with a sword',
#   'a man is cutting a bottle of water with a sword',
#   'someone slices a bottle with a sword',
#   'a person slices through a bottle with a sword',
#   'the ma sliced through a plastic bottle',
#   'the man used a sword to slice a plastic bottle',
#   'a man slices the top of a plastic bottle of water off with a sword',
#   'a man breaks a bottle with a sword',
#   'the man sliced through a soda bottle with a sword',
#   'the man cut the bottle with the sword',
#   'a person is break out the bottle',
#   'a man cuts a bottle with a sword',
#   'i love the cold steel blades',
#   'a person cutting a botal',
#   'the person is doing the something',
#   'a man is cutting a bottle of soda',
#   'a man is breaking a bottle',
#   'a man slices a soda bottle with a sword',
#   'a man sliced a bottle full of liquid with a cold steel sword in an instant',
#   'a man slices a soda bottle in half with a sword',
#   'a man breaking a glass',
#   'the man is using a sword to slice the platic bottle',
#   'a man is standing with road',
#   'cold steel swords video',
#   'a man is slashing a bottle with a sword',
#   'a man is broken a bottle'],
#  '-8y1Q0rA3n8_95_102': ['a man with a sword runs ands stabs a cardboard target',
#   'a man with a sword stabs a target',
#   'a man with a sword stabs a target',
#   'a man is stabbing a cardboard cutout with a sword',
#   'a man stuck a sword through a piece of paper',
#   'a man is hitting a photo with his sword',
#   'a man is demonstrating a sword',
#   'a man is stabbing a target',
#   'someone is stabbing a poster with a sword',
#   'a man is stabbing a silhouette with a sword',
#   'the man stabbed the picture as he ran by',
#   'the man used a sword stab the target',
#   'a person stabs a photo print with a knife',
#   'the man pierced the picture with a sword as he ran by',
#   'a man using a sword',
#   'a man showing a sword act',
#   'a man puts a sword into a target',
#   'a men is presenting show',
#   'the boy is doing the something',
#   'a man cutting photo with a sword',
#   'a man is running',
#   'a man breaking the photo',
#   'man is advertising of sward',
#   'a man thrust the sword in a cutout',
#   'a man is running with a sword then stabbing it into a picture of an asian man',
#   'the man stabbed the target with a sword',
#   'a man is pionting a photo with a swoard'],
#  '-9CUm-2cui8_39_44': ['a woman puts four okra in a pan of boiling water',
#   'a woman is boiling peppers',
#   'a person is boiling chile peppers',
#   'someone is cooking okra in a pan',
#   'a woman is boiling finger in the water',
#   'a woman is adding cut green beans to boiling water',
#   'a woman is boiling some vegetables',
#   'okra is cooking in boiling water',
#   'someone is boiling some peppers',
#   'a woman is adding vegetables to a pot',
#   'the lady added the pea pods to the boiling water',
#   'the woman is boiling okra',
#   'a woman is boiling okra',
#   'a woman dumps vegetables into boiling water',
#   'ocra is boiling in a pot of water',
#   'someone is boiling okra in a pot',
#   'the lady put the bean pods in the boiling water',
#   'there is a preparing curry',
#   'a lady is stirring the lady finger which is in the boiling water',
#   'someone is boiling peppers',
#   'the person is the boiling the ladiesfinger',
#   'a woman is putting some okra into a pot',
#   'a chef is boiling vegetables in water',
#   'someone boiling lady finger in frying pan',
#   'the lady put the pea pods in the boiling water',
#   'a man cooking his kichen',
#   'the woman is boiling okra',
#   'a woman boils okra'],
#  '-AwoiGR6c8M_10_14': ['a boy is playing a keyboard',
#   'a boy is playing a piano',
#   'a boy is playing a piano',
#   'a boy is playing piano',
#   'a boy is playing piano',
#   'a boy is playing the piano',
#   'a boy is playing the piano',
#   'a boy is playing the piano',
#   'a boy is sitting in a room playing a piano by lamp light',
#   'a boy plays a piano',
#   'a boy plays the piano',
#   'a boy plays the piano',
#   'a boy seated in a room is playing the piano',
#   'a kid is playing a piano',
#   'a kid is playing piano',
#   'a young boy is playing the piano',
#   'a youngster is sitting on a piano',
#   'the boy is playing the piano',
#   'the boy practiced his piano',
#   'the boy practiced the piano',
#   'a boy singing a song while playing piano',
#   'a boy playing music',
#   'the girl is playing the nusic',
#   'a guy is sitting at the piano and singing',
#   'a young boy singing a song',
#   'the boy sit and sing very nicely',
#   'greyson chance singing broken hearts',
#   'a boy is playing a piano',
#   'the boy is playing the piano',
#   'the song dance very enjoy',
#   'a kid is playing a piano',
#   'someone is playing the piano',
#   'a boy playing a guitar',
#   'a boy is playing a piano',
#   'somebody is doing something',
#   'a you boy playing on a piano',
#   'a boy playing piano',
#   'a boy play the piano',
#   'a boy is playing piano',
#   'a girl playing piyano',
#   'a boy is playing the piano',
#   'very melody music video',
#   'a boy is playing a piano',
#   'a boy is playing the piano'],
#  '-Cv5LsqKUXc_17_25': ['a man is slicing strawberry',
#   'a men is removing a stem of strawberry for making ichigo daifuku strawberry daifuku',
#   'a woman is removing stems from a strawberry',
#   'a woman is slicing a strawberry',
#   'chopping stroubery',
#   'someone is cutting the leafy parts off of some strawberries',
#   'the stem',
#   'she teaching strobery food making',
#   'a chef cuts the leaves off of strawberries',
#   'a chef is cutting strawberries head',
#   'a cook is cleaning strawberry by removing the leaves',
#   'a man cuts the leaves off of strawberries',
#   'a man cuts the tops off of three strawberries',
#   'a man is cutting the top leaves off of three strawberries',
#   'a man slices the top off a strawberry',
#   'a man slicing the greens off of strawberries',
#   'a person is cutting the stems off of strawberries',
#   'a person is cutting the tops off strawberries with a knife',
#   'a person is slicing off the stems of strawberries',
#   'a person is slicing strawberries',
#   'a woman chopping off the strawberrys stalks',
#   'a woman chopping the stalks off of strawberries',
#   'a woman is chopping the stem off from prewashed strawberries using a knife',
#   'a woman is cutting the stems off strawberries',
#   'a woman is preparing strawberry daifuku',
#   'a woman is removing head of strawberry',
#   'a woman is using a knife to remove the head from strawberries',
#   'a woman removing a stems from strawberry',
#   'a woman removing the stems of strawberries',
#   'cutting the top postion leafy postion strawberry fruit',
#   'someone cutting the stems off of strawberries',
#   'someone is slicing the tops off some strawberries',
#   'the man removed the stems over pre washed strawberries',
#   'the person is slicing the top off the strawberries',
#   'the top leafy part of the strawberry is being cut',
#   'the top part of the strawberry is being removed',
#   'the tops of three strawberries are cut off',
#   'the women is making strawberry daifuku',
#   'woman cutting tops off strawberries',
#   'a woman is cutting unwanted part of strawberry fruits',
#   'a woman showing how to make strawberry daifuku',
#   'cutting the straw berry'],
#  '-Cv5LsqKUXc_71_76': ['a powdered substance is being shifted into a pan',
#   'a woman sifting flour or sugar through a siv',
#   'filter something',
#   'preparing sweet with strawberry',
#   'the baking sheet is dusted with flour',
#   'a man sifting flour into a cake pan',
#   'a pan is being floured',
#   'a person dusts a baking tray with starch powder using a sieve',
#   'a person is using a sift to sprinkle flour onto a pan',
#   'a woman flours a pan',
#   'a woman is dusting a pan with white flour',
#   'a woman is filtering flour',
#   'a woman is filtering some food powder',
#   'a woman is filtering some powder',
#   'a woman is filtering sugar powder',
#   'a woman is preparing daifuku',
#   'a woman is preparing strawberry daifuku',
#   'a woman is shaking sugar into a pan',
#   'a woman is sifting flour in a baking dish',
#   'a woman is sifting powdered sugar onto a baking sheet',
#   'a woman is sifting sugar',
#   'a woman is spreading a power in baking sheet',
#   'a woman mixing ingredients together',
#   'a woman sifting baking starch',
#   'a woman sifting sugar',
#   'a woman sifts flour into a metal pan',
#   'filtering the ingredients',
#   'flour is loosen over a plater',
#   'nothing on video',
#   'sifting powered sugar through strainer',
#   'someone is flouring a baking pan',
#   'someone scatter a tray with powder sugar',
#   'the cook is sprinkling flour on the bottom of the pan',
#   'the flour is being sieved on to a tray',
#   'the lady is straining the starch powder',
#   'the man was sieving the power with a sieve',
#   'woman is coating baking pan with powdered sugar',
#   'make strobery food'],
#  '-DKuLXYoY3g_14_20': ['a boy is playing',
#   'a kidd plays basketball',
#   'a young boy practices dribbling a basket ball inside of a gym',
#   'ahild is playing a basket ball',
#   'a boy dribbles a basketball',
#   'a boy is bouncing a ball',
#   'a boy is dribbling a basketball',
#   'a boy is dribbling a basketball',
#   'a boy is playing with ball',
#   'a boy is take a practice for basketball',
#   'a boy is trying to dribble a basketball',
#   'a child tries his best to dribble a ball',
#   'a kid dribbling a basketball',
#   'a kid is dribbling a basketball',
#   'a kid is dribbling basketball',
#   'a little boy bounces a basketball',
#   'a little boy is bouncing a basketball on a basketball court',
#   'a little boy is dribbling a basketball on the court',
#   'a little boy is dribbling a basketball',
#   'a little boy is dribbling a basketball',
#   'a little boy was trying to dribble a basketball',
#   'a small boy is tapping the basket ball',
#   'a young boy is bouncing a basketball in a gym',
#   'a young boy is bouncing a basketball',
#   'a young boy is dribbling a basketball',
#   'a young boy is dribbling a basketball',
#   'a young boy is trying to dribble a basketball',
#   'a young boy practices dribbling a basketball',
#   'a young boy trying to dribble a basketball',
#   'an asian kid learning basketball',
#   'boy is bouncing basketball',
#   'in video a boy is playing with a ball on bassket ball court',
#   'little boy is learning how to dribble a basketball',
#   'one young boy is playing basket ball',
#   'small boy taping basket ball',
#   'the boy is playing with the basketball',
#   'the child is dibbling the basket ball',
#   'the small boy tried dibbling the basketball',
#   'this child is learning to play basketball'],
#  '-DRy7rBg0IQ_31_37': ['a girl swimming under water',
#   'a female swimmer pushes off the side of pool underwater',
#   'a girl is kicking off her swim from the side of a swimming pool',
#   'a girl pushes off from the side of the pool',
#   'a girl swims underwater',
#   'a swimmer pushes off the wall and swims',
#   'a woman glides underwater after pushing off from the wall at one end of the pool',
#   'a woman is swimming in the swimming pool',
#   'a woman is swimming underwater',
#   'a woman is swimming',
#   'a young woman is swimming under water',
#   'the woman is swimming under water',
#   'a woman is swimming',
#   'a girl is swimming under water',
#   'a woman pushes off the wall while swimming',
#   'swimmer swimming under water',
#   'swimming in a pool',
#   'nice swimming',
#   'a female swimmer is pushing herself off the wall of a pool with her feet',
#   'a girl is starting a swimming series',
#   'a girl is swimming underwater',
#   'a girl is swimming underwater',
#   'a lady is swiming in a pool',
#   'a swimmer shows her talent',
#   'a woman in a blue swimsuit diving in the pool',
#   'a woman is swimming in a pool',
#   'a woman is swimming in a swimming pool',
#   'a woman is swimming under water',
#   'a woman is swimming underwater',
#   'a woman is swimming underwater',
#   'a woman is swimming',
#   'a woman is swimming',
#   'a woman is swimming',
#   'a woman is swimming',
#   'a woman starting to swing in a swimming pool',
#   'a woman starts swimming underwater in a swimmingpool',
#   'a woman swimming underwater',
#   'a woman swims underwater',
#   'a woman swims underwater',
#   'a women is swimming beneath the water',
#   'the girl pushed off from the swimming pool wall',
#   'the lady is swimming',
#   'the swimmer pushed off the pool wall',
#   'the woman is swimming under water',
#   'a lady is swimming under water in the pool'],
#  '-FugkxLmGO4_5_16': ['a husky and her pup stare happily out of a cage',
#   'a baby husky standing in an enclosure along with an adult husky is squealing in response to a human voice',
#   'a dog and a puppy are in a cage',
#   'a dog and a puppy are standing in a basket',
#   'a dog and a puppy on in a topless cage',
#   'a dog and a puppy sit in a cage',
#   'a dog and puppy are in a cage',
#   'a husky and its puppy are in a pen',
#   'a large dog and a puppy are being kept in a portable dog pen',
#   'a large dog and a small dog are in a cage together',
#   'a puppy and dog are standing in a cage',
#   'one dog walks around a cage while the another sits',
#   'the dog and her puppy looked at from their cage',
#   'the dog and puppy waited in the pen',
#   'the two dogs were in the pen',
#   'two dogs are in a cage',
#   'two dogs are standing in a cage',
#   'two dogs watch from a cage',
#   'a dog and a puppy are standing',
#   'a dog and its puppy are in a pen',
#   'a dog with her pet',
#   'a dog with her puppy in the cage',
#   'a husky and it s pup move about',
#   'a new born animal is inside the cage',
#   'baby husky with a husky',
#   'dogs doing some kind of funny acts',
#   'one dog with little puppy looking around',
#   'the dog and puppy',
#   'a baby and mother husky is inside a cage',
#   'a baby dog husky',
#   'a baby husky is in a cage with a larger husky that is walking around and sniffing it',
#   'a baby of husky',
#   'a dog and a puppy are in the cage',
#   'a dog and a puppy in a pen',
#   'a dog and its puppy is in a cage',
#   'a dog is in the cage',
#   'a dog moving with a puppy in a cage type home',
#   'a dog with its puppy',
#   'a grown husky and a baby husky are standing in a cage',
#   'a husky puppy and its mother are sitting in a pen',
#   'a mother and baby husky dog in a pen',
#   'a puppy is seeing out of its sell',
#   'baby husky',
#   'the dog is trying to come out',
#   'two dogs are in a cage',
#   'the dogs trying to the coming to the out side',
#   'the dog and puppy in the net'],
#  '-Ms9tsWmhyU_80_95': ['a flute is played',
#   'a girl is playing an instrument',
#   'a person is playing a flute',
#   'a person is playing the flute',
#   'a woman is playing a flue',
#   'a woman is playing a flute',
#   'a woman is playing a flute',
#   'a woman is playing a flute',
#   'a woman is playing a flute',
#   'a woman is playing a flute',
#   'a woman is playing flute',
#   'a woman is playing the flute',
#   'a woman is playing the flute',
#   'a woman plays a flute',
#   'a woman plays the flute',
#   'the lady played the flute',
#   'the man played the flute',
#   'the woman is playing the flute',
#   'the person is playing flute',
#   'nina perlove teaching the flute',
#   'a man is playing a flute',
#   'a lady is playing the flute',
#   'the person is playing flute',
#   'she is playing the flute in her bathroom',
#   'a man is playing some instrument',
#   'a woman is playing a flute',
#   'a lady is playing flute',
#   'a woman is playing a flute',
#   'a woman playing a flute',
#   'a woman is playing a flute',
#   'a boy is playing flute',
#   'a girl is playing an instrument',
#   'a woman is playing a flute',
#   'a woman plays the flute',
#   'a person is plating fluit',
#   'a woman playing flute',
#   'the lady played her flute',
#   'a woman is playing the clarinet',
#   'a girl is playing music',
#   'a woman plays a flute',
#   'a woman is playing the flute',
#   'a man is playing on flute',
#   'a woman is playing the flute',
#   'please excuse me'],
#  '-YI0cxuNcq8_262_272': ['a woman demonstrating abdominal exercises',
#   'a girl is exercising',
#   'a girl is exercising',
#   'a lady did exercises on a mat',
#   'a woman does exercises on a floor mat',
#   'a woman exercise her ab muscles on a floor mat',
#   'a woman is doing exercise in the room',
#   'a woman is doing exercises on the floor',
#   'a woman is doing exercises',
#   'a woman is exercising her abs',
#   'a woman is exercising on the floor',
#   'a woman is exercising on the floor',
#   'a woman is exercising',
#   'a woman is exercising',
#   'a woman is exercising',
#   'a woman is laying on her back on a mat and she is exercising',
#   'a woman is performing some floor exercises',
#   'a woman is working out',
#   'a woman lying on her back on an exercise mat is moving her legs back and forth and her head from side to side',
#   'the girl exercised on a mat',
#   'the woman is exercising',
#   'a girl doing excercise on the floor',
#   'a women doing exercise',
#   'the women is excising',
#   'the woman is doing cyclic exercise',
#   'a woman is doing exercise',
#   'the lady is showing 15minute abs workout',
#   'a woman is exercising',
#   'a woman is demonstrating ab exercises',
#   'a lady is doing exercise',
#   'a woman is exercising',
#   'a girl is practicing the yoga on the floor',
#   'a woman is doing healthful exercise',
#   'a woman is laying on the floor doing abdominal exercises',
#   'a girl is doing exercise',
#   'a woman is working out on a yoga pad',
#   'a woman is doing exercise on floor',
#   'a lady is doing a excercise',
#   'a woman is exercising',
#   'woman doing exercise',
#   'one girl doing exercise',
#   'a woman is doing aerobics',
#   'a woman doing some sort of abe workout',
#   'the lady demonstrates the tips of aerobics',
#   'a woman is exercising on a blue yoga mat',
#   'a woman is excersizing',
#   'a lady is exercising',
#   'women showing how to do exercise',
#   'a woman playing workout',
#   'a young woman is exercising on a mat',
#   'a woman is exercising on a mat',
#   'a lady is doing workout',
#   'she is excise',
#   'a woman is doing exercise on a floor mat',
#   'a woman exercises'],
#  '-_aaMGK6GGw_57_61': ['a man grabs a boy',
#   'a man and woman are yelling at a young boy and suddenly the scene shifts to a woman and a sleeping bearded man',
#   'a dad beats his kid',
#   'a man tossed a woman into a chair',
#   'a man is pushing a woman to chair',
#   'a man is pushing a boy into a chair',
#   'a man is throwing a child into a chair',
#   'a man throws a kid into a chair',
#   'a boy is getting thrown down',
#   'people are talking',
#   'a man throws a boy into a chair by his arm',
#   'shouting angrily',
#   'the man grabbed a boy and threw him into a chair',
#   'the man and woman are yelling at the boy',
#   'adults discipline a child',
#   'a man knocks a boy down',
#   'the man threw the boy into a chair',
#   'the boy is smoking',
#   'a father shoting at son',
#   'a man slams a boy into a chair',
#   'a man is beating to a lady',
#   'a men and women is fighting',
#   'two adults are shouting in anger at a teenager',
#   'they are fighting',
#   'a young man smoking',
#   'a man is arguing',
#   'a man grabs a boy',
#   'a man is pushing the lady in the film sequence',
#   'the man is pushing the child',
#   'a man is smoking',
#   'an older man takes a boy by the arm and throws him into a chair',
#   'the police hitted to boy',
#   'a man is yelling',
#   'a boy fighting',
#   'two people talk to a boy',
#   'people are talking eachother',
#   'a man hitting another man and pull him down',
#   'a person is talking to a girl',
#   'parents are scolding a child',
#   'a man angrily pulls a teen aged boy on to the couch',
#   'a man is scolding her daughter by pulling',
#   'a man grabs a child by the arm and throws him into a chair',
#   'a man is beating a another man'],
#  '-_hbPLsZvvo_172_179': ['a person is mixing ingredients in a bowl',
#   'a woman is adding all ingredient into the bowl',
#   'a woman is adding ingredients into a bowl',
#   'a woman is adding ingredients to a bowl',
#   'a woman is adding vinegar',
#   'a woman is mixing food in a bowl',
#   'a woman is mixing ingrediants',
#   'a woman is pouring ingredients into a bowl',
#   'a woman is pouring oil and seasoning into a bowl of cut up vegetables',
#   'a woman is preparing some food',
#   'a woman is putting ingredients in a bowl',
#   'a woman is putting ingredients into a bowl',
#   'a woman mixes food in a bowl',
#   'a woman puts various ingredients into a bowl',
#   'a woman seasons a vegetable mixture',
#   'the lady added oil and seasoning to the vegetables',
#   'the lady poured ingredients into the vegetable mixture',
#   'the woman is seasoning the mixture',
#   'woman making some japanese food',
#   'the woman is cooking',
#   'a woman is preparing food',
#   'how to make bento',
#   'a woman puts ingredients into a bowl',
#   'a japanese lady making food',
#   'someone is adding ingredients to a dish containing mandarin oranges',
#   'a woman is mixing some ingredients',
#   'a woman is preparing food',
#   'someone is mixing food',
#   'a woman is putting ingredients into a bowl',
#   'showing how to make bento',
#   'a woman adds several ingredients to a bowl',
#   'a short clip showing some sort of food items packed in a lunch box',
#   'she is making bento',
#   'a chinese lady demonstrating how to make a chinese dish named bento with her dog',
#   'a women cook with her dog',
#   'a man cooking his kichen',
#   'a women making banto',
#   'adds a bit of vinegar',
#   'vegetables are being seasoned in a mixing bowl',
#   'the woman is seasoning the carrots',
#   'a woman demonstrating a recipe',
#   'a woman is adding ingredients to a bowl',
#   'a woman is pouring a vinegar',
#   'a woman stirs a combination of vegetables'],
#  '-_hbPLsZvvo_18_25': ['a woman cuts a piece of zucchini in half and ten thinly slices it',
#   'a woman slices a cucumber',
#   'a woman is slicing cucumber',
#   'a woman is slicing a cucumber into pieces',
#   'a woman slices a cucumber',
#   'a woman is cutting a cucumber with a knife',
#   'a woman is cutting a cucumber',
#   'a woman is slicing cucumbers',
#   'a woman is cutting cucumber',
#   'a woman is slicing a cucumber with a large knife',
#   'a woman is cutting',
#   'someone is cutting a cucumber',
#   'someone is slicing a vegtable',
#   'a woman is slicing a cucumber',
#   'the lady sliced the cucumber',
#   'the woman is slicing cucumbers',
#   'a woman cuts vegetables',
#   'the lady cut up a cucumber',
#   'a person making bento',
#   'a woman is cutting a cucumber',
#   'a lady is cutting a vegetable',
#   'a person is cutting bento',
#   'a woman coking',
#   'a woman is cutting a cucumber',
#   'a woman is cutting a cucumber',
#   'a woman is cutting up a cucumber',
#   'a woman is slicing a cucumber',
#   'a woman is slicing a cucumber',
#   'a woman is slicing fruit',
#   'a woman slices a zucchini',
#   'a woman slices cucumber',
#   'how to make bento',
#   'she is cutting the something',
#   'the woman is slicing cucumbers',
#   'a girl is cutting some vegetable'],
#  '-_hbPLsZvvo_19_25': ['a cucumber is being sliced',
#   'a man cuts a cucumber with skin into two and thereafter slices it finely',
#   'a man is a cutting cucumber',
#   'a man is slicing a cucumber into half moon shape',
#   'a man is slicing a cucumber',
#   'a man is slicing cucumber with a knife',
#   'a person cuts and slices a cucumber',
#   'a section of an oriental cucumber is cut lengthwise',
#   'someone cut up a cucumber',
#   'someone is slicing a cucumber into small pieces with a knife',
#   'someone sliced up a cucumber',
#   'the man is slicing cucumbers',
#   'vegetables are being chopped',
#   'a man is slicing cucumber',
#   'demonstration of bento making',
#   'the person is slicing cucumbers',
#   'a man is slicing avocado',
#   'someone is slicing a zucchini or a cucumber',
#   'a man is slicing a cucumber',
#   'the person is slicing cucumber into thin slices',
#   'a person is slicing a cucumber',
#   'a person is cutting a cucumber',
#   'a delicious japanese lunch',
#   'variety japanese lunch is on the table',
#   'a man is slicing a cucumber',
#   'a man is slicing an englishseedless cucumber',
#   'a man is slicing cucumber into small pieces',
#   'the chopping and preperation of vedgetables',
#   'a woman is slicing some cucumber',
#   'a poodle and a lady showing how to make bento',
#   'japanese lunch kept in a box',
#   'a man is slicing a cucumber',
#   'someone is slicing cucumbers',
#   'someone is slicing food',
#   'a man is slicing some vegetable',
#   'a person is slicing a cucumber',
#   'very very colourful lunch',
#   'a person is slicing cucumber',
#   'a man is cutting vegetable',
#   'raciepe for a japanes foode',
#   'someone cut up a cucumber',
#   'a man is slicing a vegetable',
#   'a man cooking his kichen',
#   'the cook is slicing a cucumber',
#   'a man is slicing a cucumber',
#   'a person cuts up some cucumber',
#   'a person is slicing pieces of cucumber',
#   'someone cut up a cucumber'],
#  '-_hbPLsZvvo_19_26': ['a woman is cutting a vegetable',
#   'a man cuts a piece of zucchini in half and slices it thinly',
#   'a person is slicing cucumbers',
#   'someone sliced a cucumber or a zucchini into small pieces',
#   'a person is slicing a cucumber into pieces',
#   'a chef is slicing a vegetable',
#   'a person is slicing a cucumber',
#   'a wo man is slicing vegetables',
#   'a woman is slicing a cucumber',
#   'a person is slicing cucumber with a knife',
#   'a person cuts up a piece of cucumber',
#   'a man is slicing cucumber',
#   'a man cutting zucchini',
#   'someone is slicing fruit',
#   'a person is slicing a cucumber',
#   'the lady sliced the cucumber',
#   'the man is slicing cucumbers',
#   'a woman cuts up vegetables',
#   'the lady sliced a cucumber',
#   'the person is cutting the something',
#   'a delicious japanese boxed lunch',
#   'a man is cutting a cucumber',
#   'a person is slicing cucumber',
#   'a man is cutting the cucumber',
#   'a woman is slicing a cucumber with a knife',
#   'a woman is slicing cucumber',
#   'i like this video because it is very tasty',
#   'someone is cutting up a cucumber',
#   'someone cutting the slices of cucumber',
#   'slicing a cucumber into small bites',
#   'a person coking',
#   'a chef cutting zucchini into small semicircles',
#   'one leady is chines cooking for recipe',
#   'a person is cutting vegetables',
#   'a guy is slicing a cucumber',
#   'the woman is slicing cucumbers',
#   'a woman is dicing a cucumber',
#   'any one is slicing the vegetable',
#   'a person is slicing a cucumber',
#   'a woman is slicing a cucumber',
#   'a woman is slicing cucumber',
#   'someone chops cucumber'],
#  '-_hbPLsZvvo_211_219': ['a man is scrambling eggs in a square shaped frying pan',
#   'a woman cooks scrambled eggs',
#   'a woman is cooking eggs in a pan',
#   'a woman is cooking eggs',
#   'a woman is cooking eggs',
#   'a woman is cooking some egg dish',
#   'a woman is frying scrambled eggs',
#   'a woman is pouring a yellow mixture on a frying pan',
#   'a woman is pouring an egg mixture into a frying pan',
#   'a woman is pouring scrambled eggs into a pan',
#   'a woman is putting eggs into a pan',
#   'a woman pours a beaten egg mixture into a hot pan and swirls the pan to spread it evenly',
#   'a woman pours a mixture into a pan',
#   'a woman pours eggs into a square pan',
#   'a woman putting an egg mixture into a pan',
#   'someone using chopsticks pours an egg mixture from a glass bowl into a griddlelike pan',
#   'the lady poured eggs into a hot frying pan',
#   'the lady poured the eggs into the frying pan',
#   'the woman is cooking scrambled eggs',
#   'a woman making omelet',
#   'the person is making bento',
#   'a woman is cooking eggs',
#   'a woman is cooking egg',
#   'the personis preparing something wiyh egg',
#   'a woman is cooking some eggs',
#   'a woman is cooking some eggs',
#   'japanes foods',
#   'a woman is pouring batter into a frying pan',
#   'a woman coking',
#   'a woman is cooking',
#   'a lady is making omlette',
#   'racipe for bento dish',
#   'a women making food with her dog',
#   'a woman is cooking something',
#   'a woman pours a yellow liquid onto a skillet',
#   'a women made dish',
#   'very clear making for bento',
#   'a woman is pouring eggs into a pan'],
#  '-_hbPLsZvvo_269_275': ['a chef removes fried foods from a pot',
#   'a man is frying pumpkins',
#   'a person is frying food',
#   'a person is moving food from boiling pots to a grill',
#   'a person is taking a piece of fried squash and then a piece of fried meat out of a wok',
#   'a person removes pieces of food from a pot of hot oil',
#   'a person takes meat and vegetables out of a pot',
#   'a person taking food out of a fryer',
#   'a woman is removing food from a pot of oil',
#   'a woman removes pumpkin wedges and chicken pieces after frying them in a pan and places them on a wire rack',
#   'someone fried zucchini and chicken pieces in oil',
#   'someone is frying food',
#   'someone is frying something',
#   'someone is frying vegetables',
#   'someone removes pieces of a yellow vegetable or fruit and chicken pieces from a pan of boiling liquid',
#   'the lady cooked vegetables and chicken in hot oil',
#   'the woman is frying vegetables',
#   'vegetables are placed on a skewer',
#   'a man is removing food from a pot',
#   'a person is pulling food out of a deep fryer',
#   'a person is cooking',
#   'the person is preparing something to eat',
#   'a person is making food',
#   'an attractively garnished japanese boxed lunch',
#   'food is being fried',
#   'this is how to make bento',
#   'a person is taking food out of a fryer',
#   'the person is taking out pumpkin and chicken from oil',
#   'a man is cooking',
#   'a man is frying some food',
#   'someone is drying some food',
#   'making vcvof japanese boxed lunch bento',
#   'someone is bioling pumpkin',
#   'a woman is removing food from oil',
#   'japanese dish is prepared in which the vegetable and piece of chicken is shallow fried',
#   'somebody is cooking',
#   'a woman is talking about how to make bento',
#   'a woman is frying vegetables',
#   'a person making bento',
#   'pumpkin and chicken are being cooked',
#   'pieces of goldenbrown fried pumpkin and chicken placed on awire rack',
#   'the woman is frying pumpkin',
#   'a woman is removing pumpkin and chicken pieces from a boiling pot',
#   'the man demonstrates proper technique when frying vegetables'],
#  '-_hbPLsZvvo_288_305': ['a woman is covering steamed rice in spices',
#   'a woman is forming a rice ball',
#   'a woman is forming rice into a ball',
#   'a woman is making sushi',
#   'a woman is placing rice in wrap and pressing it',
#   'a woman is prepared rice in the shape of triangles',
#   'a woman is preparing some food',
#   'a woman is wrapping rice in paper',
#   'a woman makes a rice ball',
#   'a woman molds rice into a round shape then covers them in spices',
#   'a woman molds sushi rice with plastic wrap',
#   'a woman prepares food in a kitchen',
#   'a woman puts a small bowl of steamed rice into a plastic wrap',
#   'a woman puts some rice onto a plate of vegetables',
#   'a woman shapes a ball of rice by squeezing it in plastic wrap and she then coats the rice with seasoning',
#   'the lady formed a rice cake in her hands before rolling in spices',
#   'the lady molded the rice in her hand for dipping',
#   'the woman is shaping rice and seasoning it',
#   'a women making a bento',
#   'the women is cooking something',
#   'a woman is forming and coating a rice patty',
#   'cooking demonstration by a lady',
#   'a woman is preparing sweets',
#   'a woman is preparing food',
#   'a woman makes a rice ball',
#   'a lady put the food in to the plastic',
#   'a lady is making food',
#   'a woman wraps up an onion',
#   'a woman is preparing some rice',
#   'how to make a japanese boxed lunch',
#   'a woman coking',
#   'a short clip about how to make bento',
#   'someone is putting rice in plastic',
#   'a woman is stuffing something',
#   'a chef cooking a delicacy in a triangle shape',
#   'i like very somch food',
#   'racipe for someone a food',
#   'a man cooking his kichen',
#   'a women making bento',
#   'a woman presses lukewarm steamed rice in a plastic paper to form a triangle and dabs it with a dry mixture',
#   'the woman is molding rice and wrapping seaweed around it',
#   'a woman balls up some rice and rolls it in spices'],
#  '-_hbPLsZvvo_323_328': ['a man is arranging sushi',
#   'a person is arranging food on a dish',
#   'a person is making a hot dog piece look like an octopus',
#   'a woman arranges a food dish',
#   'a woman cuts a squid',
#   'a woman is adding eyes to squash cut into ghostlike pieces',
#   'a woman is arranging some food and decorating it',
#   'a woman is decorating some food',
#   'a woman is preparing a plate of food',
#   'a woman is preparing food',
#   'a woman places sesame seeds as eyes',
#   'a woman prepares a sushi tray',
#   'sesame seed eyes are added to a sausage cut to look like an octopus',
#   'someone is decorating a cut piece of sausage with eyes',
#   'someone is decorating food on a plate',
#   'someone made the sushi look like an octopus',
#   'the lady made the sushi look like an octopus',
#   'the woman is garnishing vegetables',
#   'a woman garnish a bento dish in the serving plate',
#   'a woman is putting a vegetable on a plate',
#   'the person is showing how to make bento',
#   'a woman prepares a bento box',
#   'a person puts seeds on a hot dog',
#   'a person is placing the black thing on the food',
#   'a lady is decorating her dish',
#   'someone put two sausages on a platter',
#   'someone is preparing some food',
#   'a woman is preparing some bento',
#   'a man coking',
#   'somebody is decorating vegetables',
#   'a video on how to make bento',
#   'a person making bento',
#   'a woman plates an asian dish',
#   'a person making bento',
#   'a woman adds eyes to a piece of food to make it look like an octopus',
#   'a plate with full of fruits are displayed',
#   'the woman is garnishing the plate',
#   'how to make bento japanese boxed lunch'],
#  '-_hbPLsZvvo_43_55': ['an oriental lady is cutting a carrot into thin pieces',
#   'a woman is shown slicing a carrot into small pieces',
#   'a woman is chopping a carrot',
#   'a woman is cutting vegetables into quarter moons',
#   'a carrot is being chopped',
#   'a woman is slicing a carrot',
#   'a woman is slicing a carrot into small pieces with a knife',
#   'a woman cuts a carrot with a knife',
#   'a woman is cutting a carrot',
#   'a woman makes perpendicular cuts at one end of a carrot and thereafter slicing it thinly',
#   'a woman slicing a carrot',
#   'the woman is cutting a carrot',
#   'a woman is slicing a carrot',
#   'a woman is cutting a carrot',
#   'a lady is chopping up a carrot',
#   'a delicious food is on the table',
#   'a ledy cuting vegetable',
#   'a woman is chopping up a carrot',
#   'a woman is cutting a carrot',
#   'a woman is showing how to cut the carrot',
#   'a woman teaching how to slice food in a tv programme',
#   'how to make bento and japanese boxed lunch',
#   'there is a healthy prepared japanese boxed lunch',
#   'a japanese lady preparing lunch from potato and carrot',
#   'a short clip aboout japanese boxed lunch bento',
#   'a view of japanese boxed lunch',
#   'a woman cuts a carrot',
#   'a woman cutting a carrot using knife',
#   'a woman dices a carrot',
#   'a woman is cutting a carrot',
#   'a woman is cutting carrot into small pieces',
#   'a woman is cutting carrot',
#   'a woman is cutting carrots into small pieces with a large knife',
#   'a woman is quartering a carrot',
#   'a woman is sectioning and cutting a carrot',
#   'a woman is slicing a carrot with a knife',
#   'a woman is slicing a carrot',
#   'a woman is slicing a carrot',
#   'a woman is slicing a carrot',
#   'a woman is slicing a carrot',
#   'a woman is slicing some bentos',
#   'a woman is slicing vegetables',
#   'a woman slices a carrot',
#   'a woman slices a carrot',
#   'a woman with his dog describing about how to make bento',
#   'a women is slicing a carrot',
#   'a women is slicing carrot',
#   'how to make an easy japanese food',
#   'making of bento',
#   'the old lady slicing carrot',
#   'the person is showing how to make bento',
#   'the woman is cutting the potato',
#   'they are showing how to do bento',
#   'a girl is cutting some vegetable',
#   'a woman is slicing carrot',
#   'a women is showing how to make bento',
#   'the person is cooking something',
#   'a lady is cutting a carrot',
#   'a woman is slicing some carrot'],
#  '-_hbPLsZvvo_49_55': ['a person is slicing carrots',
#   'a woman is slicing a carrot into pieces',
#   'a chef is dicing a carrot',
#   'a woman is slicing a carrot',
#   'a woman is slicing carrot',
#   'a woman is slicing a carrot into pieces',
#   'a person is slicing a carrot',
#   'a woman cuts up a carrot',
#   'a woman is cutting a carrot',
#   'a woman is slicing a carrot',
#   'a person is slicing a carrot',
#   'a woman slices a carrot into quarter moon shaped pieces',
#   'someone cut a carrot into quarter slices',
#   'the woman is slicing carrots',
#   'a carrot is chopped up',
#   'a cook cuts carrots',
#   'the lady cut the carrot into quarters',
#   'the person is cutting the something',
#   'cutted some carets',
#   'a woman is cutting a carrot',
#   'the japaneese lady given demo for how to make the bento',
#   'a person is slicing a carrot',
#   'a person is cutting the carrot',
#   'a man is cutting carrot',
#   'a woman is cutting a carrot into quarter moons',
#   'a person are cutting a carrot',
#   'a woman is slicing a carrot',
#   'a woman is slicing a carrot',
#   'how to make bento',
#   'a person coking',
#   'someone is slicing a carrot',
#   'women slicing the carrot',
#   'a short clip about how to make bento',
#   'a women is cutting the carrot',
#   'a man cooking his kichen',
#   'a lady is slicing a carrot',
#   'a woman is chopping a carrot',
#   'a woman is slicing a carrot'],
#  '-_hbPLsZvvo_5_8': ['a dog is chewing',
#   'a dog appears to be talking next to a woman cook',
#   'a dog is barking',
#   'a dog is barking',
#   'a dog is barking',
#   'a dog is barking',
#   'a dog is chewing food',
#   'a dog is barking',
#   'a dog is eating',
#   'a dog barks',
#   'a dog is chewing something',
#   'a dog is barking',
#   'a dog is barking',
#   'a dog is chewing on food',
#   'the dog happily ate the sushi',
#   'the dog is eating',
#   'a dog barks',
#   'the dog ate the sushi',
#   'a dog is barking',
#   'a puppy is barking',
#   'a dog barking and cooking with her master in the kitchen',
#   'a women cooked a tasty food with her dog',
#   'a dog is craying',
#   'learn to make an easy japanese lunch bento',
#   'a dog is chewing',
#   'a woman making a bento',
#   'a dog is eating',
#   'a dog is barking',
#   'the dog is sitting',
#   'a lady is cooking with dog',
#   'a dog is barking',
#   'a cooking show',
#   'a dog is talking',
#   'a grey poodle barking loudly',
#   'a dog is barking',
#   'a dog barging',
#   'a dog is eating',
#   'someone is cooking',
#   'a lady cooking in her kitchen with her dog',
#   'a dog barks and then a lady in a kitchen bows',
#   'a dog is chewing',
#   'a man cooking his kichen',
#   'a person is making bento japanese boxed lunch',
#   'the dog is eating',
#   'a dog is barking',
#   'a dog barks',
#   'she is cooking',
#   'the cooking with dog',
#   'a gray poodle is barking'],
#  '-bjOB4zS0uE_100_105': ['a woman is stirring a substance in a wine glass',
#   'a girl is mixing something in a glass jar',
#   'a girl is mixing something in a glass',
#   'a woman demonstrates how to create homemade cosmetics',
#   'a woman is mixing a cream in a glass with a spoon',
#   'a woman is mixing ingredients in a glass',
#   'a woman is mixing ingredients in a glass',
#   'a woman is preparing some thing in a glass jar',
#   'a woman is stirring a jar full of a creamy substance',
#   'a woman is stirring a mixture in a glass',
#   'a woman is stirring ingredients in a glass',
#   'a woman mixes a beauty treatment in a glass',
#   'a woman mixes ingredients in a glass',
#   'a young woman mixes something up in a glass',
#   'the girl stirred a pste in a cup',
#   'the girl stirred the stuff in the glass',
#   'the woman is mixing ingredients in a glass',
#   'using a spoon',
#   'a girl is standing inside the room',
#   'a girl mixes something in a cup',
#   'a girl show how to make pore strips',
#   'a lady is applying the makeup',
#   'a lady is preparing something in a glass',
#   'a lady making pore strips',
#   'home made black head remover',
#   'how to make your own pore strips',
#   'a chinese girl demonstrating on how to make own pore strips',
#   'a chinesses babe mixing something with spoon in a pot like glass',
#   'a girl is making pore strips',
#   'a girl is mixing something in a glass',
#   'a girl is stirring mix in a glass',
#   'a girl is stirring something in a glass',
#   'a girl is wearing pore strips',
#   'a lady is stirring the thing in the glass',
#   'a woman is clearing nose pore',
#   'a woman is mixing liquid in a glass',
#   'a woman is mixing something',
#   'a woman is stiring the contents in a glass',
#   'a young woman is stirring a mixture in a glass',
#   'the girl is preparing strips'],
#  '-dm-ds5rRaM_44_52': ['ussain bolt winning a race',
#   'a group of men are sprinting on a race track towards the finish line',
#   'a group of men run a track race',
#   'athletes are competing in 100 meters race',
#   'athletes are running down the track',
#   'men are racing around a track',
#   'men are running a race',
#   'men are running in a race',
#   'runners compete in a race',
#   'runners race around a track',
#   'several runners are racing down a track when the second place runner overtakes the leader at the finish line',
#   'the men are running in a race',
#   'the racers raced on the track',
#   'the racers sprinted across the finish line',
#   'people are running in a race',
#   'usain bolt wins the 200m sprint',
#   'the person is doing running race',
#   'players are running in a competition',
#   'this is 200 meters race',
#   'men are running',
#   'athletics are running in the track',
#   'the men sprint competition',
#   'group of guys running in the race',
#   'a group of runners are sprinting around a track',
#   'a runners are running the ground',
#   'runners race around the track',
#   'several men are racing each other on a race track',
#   'thise is a running play ground',
#   'players are running in olympic race',
#   'some men are running',
#   'all people are running for a running rave',
#   'usain bolt wins 200 meter sprint',
#   'a short clip abot usain bolt sprint race',
#   'these guys compete on the track',
#   '200 meter race',
#   '8 people are running a race on a track',
#   'olympic racers are running',
#   'people are runing fast',
#   'usain bolt wins 200 meter sprint',
#   'sprinters race on track',
#   'a man is catching up to first place in a race',
#   'men are racing',
#   'usain bolt running fast',
#   'runners are running in a race'],
#  '-joBOHlg5J0_72_80': ['a woman powders her face',
#   'a girl is brushing her hand',
#   'a girl is placing makeup on her face',
#   'a girl is putting on makeup',
#   'a woman applies face makeup',
#   'a woman applies foundation to her face using a thick circular brush',
#   'a woman applies makeup to her face with a brush',
#   'a woman demonstrates how to put on makeup',
#   'a woman is applying cosmetics to her face with a brush',
#   'a woman is applying makeup to her face',
#   'a woman is applying makeup to her face',
#   'a woman is applying makeup',
#   'a woman is applying makeup',
#   'a woman is doing makeup on her face',
#   'a woman is putting makeup on her face',
#   'a woman is putting on makeup',
#   'a woman is using a brush to put makeup on her face',
#   'the girl applied powder to her face with a brush',
#   'the girl put foundation on her face with a brush',
#   'the woman is applying makeup to her face',
#   'a chinese girl demonstrating some sort of makeup tips',
#   'a girl is laughing',
#   'a girl is preparing herself',
#   'a woman is putting on her makeup',
#   'clubbing makeup tutorial',
#   'girl doing make up putting face powder on her face with the help of brush',
#   'one lady clubbing nails',
#   'a girl doing makeup',
#   'a girl is applying make up',
#   'a girl is putting on makeup',
#   'a girl is putting on makeup',
#   'a girl is smiling',
#   'a lady is doing makeup',
#   'a lass strokes and then dabs makeup on her face with brush',
#   'a woman is applying foundation with a brush',
#   'a woman is applying foundation',
#   'a woman is applying makeup to her face',
#   'a woman is applying makeup',
#   'a woman is applying something to her face',
#   'a young lady giving tips on face makeup',
#   'a young woman beautifully madeup',
#   'an asian woman is dabbing foundation powder on her face with a brush',
#   'girl gives make up tutorial',
#   'her tutorial is very nice',
#   'someone is putting makeup on',
#   'the lady is pretty',
#   'the girl is ready with make up'],
#  '-mAoVOhKy0c_4_9': ['a yellow train is driving on an track on a bridge',
#   'a train rides over a bridge',
#   'a train rides on tracks',
#   'a train is passing over the bridge',
#   'a train quickly crosses a bridge',
#   'a train is crossing a railroad track',
#   'a train goes across an overhead bridge',
#   'a train goes across a bridge',
#   'a train is crossing a bridge',
#   'a train is going by',
#   'a subway train is passing by',
#   'a high speed train zooms by',
#   'the train crossed the bridge',
#   'the train crossed the bridge',
#   'a bullet train crosses a tressel',
#   'the yellow train crossed the bridge',
#   'a fast moving train on a bridge',
#   'a train is coming down the tracks',
#   'a train is crossing over a waterway',
#   'as usual in your case',
#   'there is one train moving on the bridge',
#   'a train is running',
#   'a train rides on tracks',
#   'the bridge up to trainto move',
#   'the train is crossing the bridge',
#   'train on bridge',
#   'the train is going on the track'],
# ...
#   'a cartoon boy jumping on a net',
#   'a cartoon acrobat is performing',
#   'a cartoon character is doing circus',
#   'a cartoon man is swinging on a trapeze',
#   'an animated man drops on a net',
#   'a man is swinging on a trapeze',
#   'a person is swinging from a rope',
#   'a cartoon man jumps into a net',
#   'the trapeze artist jumped on the net before catching the bar',
#   'the man fell onto the net and went back up to the hanging bar',
#   'an animated man is falling from a trapeze onto a net and back to the trapeze',
#   'a cartoon man does a trapeze trick',
#   'the trapeze artist bounced on the net and caught the bar',
#   'a man jumping high in a cartoon',
#   'the playing the something',
#   'a man is playing with bar',
#   'a cartoon man is doing acrobat tricks',
#   'a man is performing trapeze',
#   'a cartoon man is oscillating in the swing',
#   'a man is doing circus',
#   'a man jumps onto a swinging bar',
#   'fearturing circus',
#   'an animated man is using a trapeze',
#   'a man is performibg stunts',
#   'it s clip of an animatin film',
#   'the trapeze artist bounced on the net and caught the trapeze bar',
#   'the man is swinging from a bar',
#   'a cartoon man is on the trapeze'],
#  'VahnQw2gTQY_203_210': ['a woman is cutting a vegetable',
#   'someone is cutting a potato into thin slices',
#   'a man is slicing a potato',
#   'a man is slicing a potato into thin slices',
#   'a man is cutting a potato into thin slices',
#   'a man is slicing a potato',
#   'a chef is slicing a potato',
#   'someone is slicing potatoes',
#   'a man is slicing vegetables',
#   'a person with a knife is slicing a potato',
#   'a man is slicing a potato',
#   'someone is slicing a potato',
#   'a person is slicing a potato',
#   'the lady sliced the potatoe',
#   'the man is slicing a potato',
#   'a man is slicing a potato',
#   'a man cuts vegetables',
#   'the lady sliced a potatoe',
#   'the person is cutting the alu',
#   'a cook slices potatoes',
#   'the person is cutting the item',
#   'someone is cutting up a potatoe',
#   'a man is slicing a potato',
#   'a person slices a potato',
#   'a man coking',
#   'cut your potates and not for sharpening eh then what do u use for sharpening your dick',
#   'a chef is demonstrating how to slice a potato',
#   'a person shows you a technique for slicing vegetables',
#   'a man is cutting potatoes',
#   'a man is cutting the potatoes',
#   'a man cooking his kichen',
#   'a man is slicing a potato',
#   'the man is slicing potatos',
#   'a person is slicing a potato',
#   'clear detail for knife techniques',
#   'a man is slicing a potato',
#   'a man is slicing a potato'],
#  'VahnQw2gTQY_274_280': ['a person slices a bread',
#   'someone is slicing pieces of bread from a loaf of french bread',
#   'a person is slicing a bread',
#   'a chef is slicing a loaf of bread',
#   'a man is slicing a baguette',
#   'a man is slicing bread',
#   'a person is slicing bread',
#   'a person with a knife is slicing bread',
#   'a man cuts up a loaf of bread',
#   'a man is slicing some bread',
#   'a man is cutting bread',
#   'someone is slicing bread',
#   'a man is slicing bread',
#   'the man sliced the loaf of bread',
#   'the man is slicing a loaf of bread',
#   'a person cuts up bread',
#   'the man sliced the loaf of bread',
#   'man cutting a piece of bread with knife',
#   'a person is cooking',
#   'the person is cutting the bread',
#   'a man is slicing bread',
#   'chopping potatoes with a sharp knife',
#   'a man is slicing bread',
#   'a man is demonstrating how to cut a baguette',
#   'a man is slicing a loaf of bread',
#   'a man is slicing up a loaf of bread',
#   'cutting pieces of bread',
#   'a man is slicing some bread',
#   'dude showing',
#   'a man cutting vegetables',
#   'someone is slicing bread',
#   'a man showing his knife techniques',
#   'kneife techniques the steel is not for sharpening',
#   'a person cutting with knife',
#   'a person is slicing bread',
#   'the man is slicing bread',
#   'a man is slicing a loaf of bread',
#   'clear defination for knife techniques',
#   'someone slices bread'],
#  'VahnQw2gTQY_288_293': ['the person is cutting an orange bell pepper',
#   'a person cuts up a pepper',
#   'a person slices peppers',
#   'a person is removing seeds from a capsicum',
#   'a chef is slicing up a pepper',
#   'a woman is slicing big pepper',
#   'a person is cutting a bell pepper',
#   'a person with a knife is slicing a pepper',
#   'a person slices an orange pepper',
#   'a person is cutting a pepper',
#   'someone is slicing a pepper',
#   'a man is cutting up a pepper',
#   'the lady cored the orange bell pepper',
#   'the person is taking out the seeds from the bell pepper',
#   'a person cuts up pumpkins',
#   'someone cut up the orange bell pepper',
#   'a man is slicing tomato',
#   'a person is playing',
#   'the person is cutting the potato',
#   'a man chops a pepper',
#   'a man is cutting a bell pepper',
#   'a man is cutting peppers',
#   'a man is cutting the capsicum',
#   'the person is cutting the potato',
#   'a man is cutting a capsicum',
#   'somebody is slicing the potatoes',
#   'a man is cutting a tomato',
#   'someone is cutting up a pepper',
#   'a man slices various fruit on a chopping block',
#   'a woman is slicing some tomatoes',
#   'the man is slicing a tomato',
#   'someone is slicing an orange pepper',
#   'the person is cutting the vegetables',
#   'a man slicing vegitables',
#   'the cook is cutting bell pepper',
#   'anyone is slicing the tomato',
#   'a man is slicing a pepper',
#   'these bell peppers are a piece of cake to me'],
#  'VahnQw2gTQY_298_305': ['someone is cutting red bell peppers into thin slices',
#   'a man chops a pepper',
#   'a person is slicing a capsicum',
#   'a chef slices a pepper',
#   'a man is cutting tomatoes',
#   'a person with a knife is slicing a pepper',
#   'a person dices up an orange pepper',
#   'a woman is cutting a pepper',
#   'a man slicing orange bell peppers',
#   'someone is slicing vegetables',
#   'a chef is slicing some peppers',
#   'a man stacks a couple of cut pieces of red bell pepper and slices them into thin strips using a knife',
#   'the lady sliced a bell pepper',
#   'the cook is slicing bell peppers',
#   'a man is slicing a sweet pepper',
#   'a person cuts up some oranges',
#   'someone cut up a red bell pepper',
#   'a man is cutting orange skins',
#   'a person is cooking',
#   'some one is slicis the tomato',
#   'a man is cutting peppers',
#   'a man is slicing peppers',
#   'someone show how to cut the vegetables',
#   'the person is cutting the pepper',
#   'a woman is slicing a pepper',
#   'someone is slicing some bell peppers',
#   'a women slicing some tomatoes',
#   'someone is slicing a pepper',
#   'one lady is slicing tomato',
#   'the lady sliced the orange bell pepper',
#   'someone is slicing something with a knife',
#   'awoman slicing vegitable',
#   'a man cuts a tomato',
#   'the person is slicing bell peppers',
#   'anyone is slicing vegetable',
#   'a man is slicing up peppers',
#   'clear detail for knife techniques'],
#  'VahnQw2gTQY_315_320': ['someone is cutting an onion with a large knife',
#   'a person slices an onion',
#   'a person is slicing an onion',
#   'a chef is slicing into an onion',
#   'a man is slicing an onion',
#   'a man is slicing an onion',
#   'a person is cutting an onion',
#   'a person with a knife is slicing an onion',
#   'a woman is cutting an onion',
#   'someone dicing an onion',
#   'someone is slicing something',
#   'a person is slicing an onion',
#   'the lady sliced the onion',
#   'the person is slicing onions',
#   'food is sliced',
#   'a man is preparing to dice an onion',
#   'half an onion is sliced horizontally and then vertically',
#   'a person cuts an onion',
#   'the lady sliced the onion',
#   'cutting the food',
#   'a person is cutting some items',
#   'a man is slicing an onion',
#   'in the demo how use the knife and cut the vegetables',
#   'a person is slicing an onion',
#   'a chef is cutting onion',
#   'someone is cutting an onion',
#   'he is cutting on the onion',
#   'a person is cutting the vegetables',
#   'there a man telling about the techniques to a knife',
#   'a man cooking his kichen',
#   'the woman is dicing onions',
#   'anyone is slicing vegetable',
#   'a man is slicing an onion',
#   'a man is slicing an onion'],
#  'VahnQw2gTQY_322_327': ['the person is dicing onions',
#   'a man slices an onion',
#   'someone is dicing an onion using a knife',
#   'a woman is slicing an onion into pieces',
#   'a chef is slicing an onion',
#   'someone is chopping onions',
#   'a man is slicing onion',
#   'a person is chopping and dicing an onion',
#   'a man is slicing onions with a large knife',
#   'a person with a knife is slicing an onion',
#   'a man slices and dices an onion',
#   'a woman is cutting an onion',
#   'someone is slicing onions',
#   'a person is slicing an onion',
#   'the lady chopped up an onion',
#   'the cook is dicing onions',
#   'a man is dicing an onion',
#   'a cook chops onions',
#   'the man cut up an onion',
#   'the person is cutting the potato',
#   'choping the onion',
#   'chopping potatoes with a sharp knife',
#   'a man is cutting the potato',
#   'a person is slicing an onion into pieces',
#   'someone is cutting an onion',
#   'someone is slicing an onion',
#   'a man is cutting potato',
#   'someone is cutting an onion',
#   'a person cutting potato s',
#   'kneife is cut the potatoes',
#   'a man cutting cabbage efficiently with his knife',
#   'the lady diced up the onion',
#   'a man is cutting the onion with sharp knife',
#   'a woman slicing vegitable',
#   'a man is dicing an onion',
#   'kife techniqe',
#   'someone dices onion'],
#  'VfqlfprZsaQ_75_85': ['three women in harem costumes are dancing in front of an audience',
#   'three women are dancing on stage',
#   'three women are performing a dance in front of an audience of men',
#   'three women are dancing on a stage',
#   'three women are belly dancing in front of an audience',
#   'women are dancing',
#   'some women are dancing',
#   'three women are dancing',
#   'woman are dancing',
#   'three women are dancing on stage',
#   'a woman is performing belly dance supported by two other women in front of a group of onlookers',
#   'the ladies danced in arabic costumes for the men',
#   'the women are dancing',
#   'three women dance',
#   'the ladies danced for the men',
#   'the women are dancing',
#   'the woman s are dancing on the stage',
#   'three women are dancing',
#   'three girls are dancing',
#   'girls dancing',
#   'women are dancing',
#   'three women are dancing',
#   'three girls dancing in front of audience',
#   'the three ladies danced for the men',
#   'the women are dancing',
#   'the girls are dancing'],
#  'Vg1jyL3cr60_163_186': ['a group is playing musical instruments',
#   'a band is performing out stage',
#   'a band is playing',
#   'a group of violinists are playing',
#   'a orchestra is playing instruments',
#   'a string orchestra plays',
#   'an orchestra is performing',
#   'an orchestra is playing',
#   'people are playing in an orchestra',
#   'people are playing instruments',
#   'the ladies playe their violins with the guitar player',
#   'the orchestra is performing in front of an audience',
#   'the orchestra performed',
#   'there are two women playing violins and at least two men playing guitars in some type of performance',
#   'two women are playing the violin on stage as part of a band',
#   'two women are playing violins',
#   'two women play violins',
#   'a nice musical concert',
#   'a musicians play a violin',
#   'several musicians are playing some music',
#   'the people s are singing the guitar',
#   'the boys and girls playing the nusic',
#   'the group is playing music',
#   'a band plays on a stage',
#   'tamil',
#   'the band performing on a stage',
#   'people were playing violin',
#   'an orchestra is playing music',
#   'two women are playing violin',
#   'people are playing violins and guitars',
#   'all people are playing musical instruments',
#   'few peoples are playing music instrument',
#   'people playing musical instruments',
#   '2 violin players play in an orchestra or band',
#   'all people are playing with music instruments',
#   'a group of people playing instruments',
#   'people are playing instruments',
#   'people are performing music show',
#   'some sort of people playing violin and other instruments in a concert',
#   'a musical group playing music on piano',
#   'people are playing the violin',
#   'violin on fire with a music',
#   'some people playing gitter',
#   'a chorus of violinists give a performance',
#   'the orchestra is playing',
#   'a lady is weaping',
#   'a band is playing with some violinists onstage'],
#  'ViM0JjUoqRw_10_20': ['a person is dissembling a web cam',
#   'a person is repairing a webcamera',
#   'a person is using a small screw driver to take apart a web cam',
#   'someone is taking a small camera apart',
#   'a person is removing part of a usb camera with a small screwdriver',
#   'someone is opening something with a screwdriver',
#   'someone is fixing something',
#   'a man used a screwdriver to open an electrical box',
#   'the man used a screwdriver to open a box up',
#   'a person is searching his screw drivers',
#   'a man is repairing the charger',
#   'a man is trying to open a usb spy camera with screw driver',
#   'a man is using tools',
#   'a person is repairing a webcamera',
#   'usb spy camera looks nice',
#   'a person is dismantling a camera',
#   'how to make a usb spy camera',
#   'a man is saying about how to make usb spy camera',
#   'a person is using camera',
#   'a man is selecting screwdrivers',
#   'a guy is dismantling a usb camera with a screwdriver set',
#   'the man is taking apart a charger',
#   'how to make usb spy camera video',
#   'a man is screwing a spy camera',
#   'someone works on a tiny camera with a screwdriver'],
#  'ViWQUOGIaSU_9_16': ['a ballerina dances on a stage',
#   'a ballerina dances',
#   'a ballerina is dancing',
#   'a ballerina is performing on a stage',
#   'a ballet dancer is performing on stage',
#   'a girl is ballet dancing',
#   'a girl is dancing on a stage',
#   'a girl is dancing',
#   'a girl is performing as a ballerina',
#   'a woman dances',
#   'a woman in a tutu is ballet dancing',
#   'a woman is dancing',
#   'a woman is doing ballet',
#   'a woman is performing a ballet dance on stage under spotlight',
#   'the ballerina danced on her toes',
#   'the ballerina danced on the stage',
#   'the ballerina is dancing',
#   'a girl performing the bally dance',
#   'the girl is dancing',
#   'a girl is performing a stage program',
#   'dancing girl',
#   'a ballerina is dancing',
#   'a ballerina is dancing',
#   'the lady is dancing very cute',
#   'a woman is dancing',
#   'a girl is dancing',
#   'a girl is dancing',
#   'a girl is dancing',
#   'a ballerina in white is dancing',
#   'a woman is dancing',
#   'a girl dancing',
#   'a woman is dancing',
#   'a woman is dancing',
#   'a person is dancing',
#   'a artist dancing in a movie trailer',
#   'the ballerina is dancing',
#   'sequence of a movie',
#   'a girl is dancing',
#   'a women is talking',
#   'excellent trailer',
#   'a girl is dancing in a dark room',
#   'a ballerina is dancing',
#   'a ballerina is dancing'],
#  'Vn0Xv0fb1z4_18_30': ['two lions',
#   'lions are watching tv',
#   'lions are watching tv on a couch',
#   'two lions are sitting on a sofa watching tv',
#   'two lions are watching a tv',
#   'a couple of lions are sitting on a couch watching tv',
#   'lions are watching tv',
#   'two lions are sitting on the couch watching television',
#   'lions are watching television',
#   'two lions watch television',
#   'two lions are watching television',
#   'two lions are watching television',
#   'two lions are watching television',
#   'the lions are watching television',
#   'two lions are lying on the couch watching television',
#   'two lions watch tv',
#   'a couple of lions are sitting on a couch and watching television',
#   'the lions sat on the couch and watched a wildlife show',
#   'the loines are watching television',
#   'lions are watching television',
#   'two lions are watching tv',
#   'lions talking and watching television',
#   'featuring a lion',
#   'a male and a female lion are watching tv',
#   'lion and tiger are watching the tv',
#   'two lions are watching television',
#   'the lions sat on the couch watching a wildlife show',
#   'a lion is playing',
#   'the lions are watching television',
#   'two tiger are watching tv'],
#  ...}
